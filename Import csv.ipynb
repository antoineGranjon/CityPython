# %%
import pandas as pd
import numpy as np

# %%
import csv

# %%
city=pd.read_csv('villes_france.csv', names=['ville_id', 'ville_departement', 'ville_slug', 'ville_nom', 'ville_nom_simple', 'ville_nom_reel', 'ville_nom_soundex', 'ville_nom_metaphone', 'ville_code_postal', 'ville_commune', 'ville_code_commune', 'ville_arrondissement', 'ville_canton', 'ville_amdi', 'ville_population_2010', 'ville_population_1999', 'ville_population_2012', 'ville_densite_2010', 'ville_surface', 'ville_longitude_de', 'ville_latitude_deg', 'ville_longitude_grd', 'ville_latitude_grd', 'ville_longitude_dms', 'ville_latitude_dms', 'ville_zmin', 'ville_zmax'], header=None)

# %%
city
# Out:
#        ville_id ville_departement             ville_slug  \
# 0             1                 1                   ozan
# 1             2                 1  cormoranche-sur-saone
# 2             3                 1              plagne-01
# 3             4                 1                tossiat
# 4             5                 1               pouillat
# ...         ...               ...                    ...
# 36695     36825               976                   sada
# 36696     36826               976               tsingoni
# 36697     36827               971          st-barthelemy
# 36698     36828               971              st-martin
# 36699     36830               975  st-pierre-et-miquelon
#
#                       ville_nom       ville_nom_simple  \
# 0                          OZAN                   ozan
# 1         CORMORANCHE-SUR-SAONE  cormoranche sur saone
# 2                        PLAGNE                 plagne
# 3                       TOSSIAT                tossiat
# 4                      POUILLAT               pouillat
# ...                         ...                    ...
# 36695                      SADA                   sada
# 36696                  TSINGONI               tsingoni
# 36697          SAINT BARTHELEMY          st barthelemy
# 36698              SAINT MARTIN              st martin
# 36699  SAINT PIERRE ET MIQUELON  st pierre et miquelon
#
#                  ville_nom_reel ville_nom_soundex ville_nom_metaphone  \
# 0                          Ozan              O250                 OSN
# 1         Cormoranche-sur-Saône         C65652625          KRMRNXSRSN
# 2                        Plagne              P425                PLKN
# 3                       Tossiat              T230                 TST
# 4                      Pouillat              P430                 PLT
# ...                         ...               ...                 ...
# 36695                      Sada              S300                  ST
# 36696                  Tsingoni             T2525               TSNKN
# 36697          Saint-Barthélemy          S5316345            SNTPR0LM
# 36698              Saint-Martin           S535635             SNTMRTN
# 36699  Saint-Pierre-et-Miquelon        S531635245               SNTPR
#
#       ville_code_postal  ville_commune  ... ville_densite_2010  ville_surface  \
# 0                 01190            284  ...                 93           6.60
# 1                 01290            123  ...                107           9.85
# 2                 01130            298  ...                 20           6.20
# 3                 01250            422  ...                138          10.17
# 4                 01250            309  ...                 14           6.23
# ...                 ...            ...  ...                ...            ...
# 36695             97640            616  ...                933          10.92
# 36696             97680            617  ...                300          34.76
# 36697             97133            123  ...                372          24.00
# 36698             97150            127  ...                695          53.20
# 36699             97500            501  ...                 25         242.00
#
#        ville_longitude_de  ville_latitude_deg  ville_longitude_grd  \
# 0                 4.91667            46.38330               2866.0
# 1                 4.83333            46.23330               2772.0
# 2                 5.73333            46.18330               3769.0
# 3                 5.31667            46.13330               3309.0
# 4                 5.43333            46.33330               3435.0
# ...                   ...                 ...                  ...
# 36695            45.10470           -12.84860                  NaN
# 36696            45.10700           -12.78970                  NaN
# 36697           -62.83330            17.91670                  NaN
# 36698            18.09130           -63.08290                  NaN
# 36699            46.71070             1.71819                  NaN
#
#        ville_latitude_grd  ville_longitude_dms  ville_latitude_dms  \
# 0                 51546.0              45456.0            462330.0
# 1                 51379.0              44953.0            461427.0
# 2                 51324.0              54342.0            461131.0
# 3                 51268.0              51854.0            460828.0
# 4                 51475.0              52542.0            461938.0
# ...                   ...                  ...                 ...
# 36695                 NaN                  NaN                 NaN
# 36696                 NaN                  NaN                 NaN
# 36697                 NaN                  NaN                 NaN
# 36698                 NaN                  NaN                 NaN
# 36699                 NaN                  NaN                 NaN
#
#        ville_zmin  ville_zmax
# 0           170.0       205.0
# 1           168.0       211.0
# 2           560.0       922.0
# 3           244.0       501.0
# 4           333.0       770.0
# ...           ...         ...
# 36695         NaN         NaN
# 36696         NaN         NaN
# 36697         NaN         NaN
# 36698         NaN         NaN
# 36699         NaN         NaN
#
# [36700 rows x 27 columns]

# %%
city.sort_values('ville_population_2012')
# Out:
#        ville_id ville_departement ville_slug  ville_nom ville_nom_simple  \
# 27135     27136                66  casefabre  CASEFABRE        casefabre
# 3223       3224                 9     tignac     TIGNAC           tignac
# 20416     20417                54   vennezey   VENNEZEY         vennezey
# 36370     36371                2B      erone      ERONE            erone
# 36371     36372                2B       lano       LANO             lano
# ...         ...               ...        ...        ...              ...
# 2049       2050                 6       nice       NICE             nice
# 11718     11719                31   toulouse   TOULOUSE         toulouse
# 28152     28153                69       lyon       LYON             lyon
# 4439       4440                13  marseille  MARSEILLE        marseille
# 30437     30438                75      paris      PARIS            paris
#
#       ville_nom_reel ville_nom_soundex ville_nom_metaphone  \
# 27135      Casefabre              C160               KSFBR
# 3223          Tignac              T252                TKNK
# 20416       Vennezey              V520                 FNS
# 36370          Érone              E650                 ERN
# 36371           Lano              L500                  LN
# ...              ...               ...                 ...
# 2049            Nice              N200                  NS
# 11718       Toulouse              T420                 TLS
# 28152           Lyon              L500                 LYN
# 4439       Marseille              M624                MRSL
# 30437          Paris              P620                 PRS
#
#                                        ville_code_postal  ville_commune  ...  \
# 27135                                              66130             40  ...
# 3223                                               09110            311  ...
# 20416                                              54830            561  ...
# 36370                                              20244            106  ...
# 36371                                              20244            137  ...
# ...                                                  ...            ...  ...
# 2049                             06000-06100-06200-06300             88  ...
# 11718                31000-31100-31200-31300-31400-31500            555  ...
# 28152  69001-69002-69003-69004-69005-69006-69007-6900...            123  ...
# 4439   13001-13002-13003-13004-13005-13006-13007-1300...             55  ...
# 30437  75001-75002-75003-75004-75005-75006-75007-7500...             56  ...
#
#       ville_densite_2010  ville_surface  ville_longitude_de  \
# 27135                  5           6.99             2.61667
# 3223                   5           3.53             1.78333
# 20416                 13           3.43             6.46667
# 36370                  1           3.89             9.27056
# 36371                  2           8.15             9.24751
# ...                  ...            ...                 ...
# 2049                4773          71.92             7.25000
# 11718               3734         118.30             1.43333
# 28152              10117          47.87             4.84139
# 4439                3535         240.62             5.37639
# 30437              21288         105.40             2.34445
#
#        ville_latitude_deg  ville_longitude_grd  ville_latitude_grd  \
# 27135             42.6167                309.0             47351.0
# 3223              42.7500               -602.0             47496.0
# 20416             48.4500               4591.0             53827.0
# 36370             42.3723               7704.0             47080.0
# 36371             42.3828               7679.0             47092.0
# ...                   ...                  ...                 ...
# 2049              43.7000               5480.0             48558.0
# 11718             43.6000               -994.0             48449.0
# 28152             45.7589               2783.0             50843.0
# 4439              43.2967               3377.0             48107.0
# 30437             48.8600                  9.0             54289.0
#
#        ville_longitude_dms  ville_latitude_dms  ville_zmin  ville_zmax
# 27135              23653.0            423658.0       236.0       664.0
# 3223               14742.0            424446.0       720.0      1440.0
# 20416              62806.0            482640.0       267.0       303.0
# 36370              91614.0            422220.0       429.0       982.0
# 36371              91451.0            422258.0       414.0      1335.0
# ...                    ...                 ...         ...         ...
# 2049               71606.0            434207.0         0.0       520.0
# 11718              12631.0            433616.0       115.0       263.0
# 28152              45029.0            454532.0       162.0       312.0
# 4439               52235.0            431748.0         0.0       640.0
# 30437              22040.0            485136.0         0.0         0.0
#
# [36700 rows x 27 columns]
