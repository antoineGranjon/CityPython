# %%
from apps.cities.cities import prepare_data_from_csv, rename_dataframe_columns_cities, dataframe_to_dict, store_datas_in_dbb
from apps.schools.schools import prepare_data_from_csv_schools, rename_dataframe_columns_schools, reduce_dataframe_schools
from apps.schools.merge import merge_cities_and_schools, show_graphe_merged_cities_and_schools
from apps.cities.models import City
from apps.schools.models import School
from database import db


if __name__ == '__main__':
    db.close()
    db.connect()
    cities = prepare_data_from_csv()
    cities_dataframe_renamed = rename_dataframe_columns_cities(cities)
    dic_cities = dataframe_to_dict(cities_dataframe_renamed)
    q = City.delete()
    q.execute()
    cities_stored = store_datas_in_dbb(dic_cities, City)
    cities_dbb = City.select().dicts()
    print(list(cities_dbb))
    merged_dataframe = merge_cities_and_schools()
    reduced_df_schools = reduce_dataframe_schools(merged_dataframe)
    renamed_df_schools = rename_dataframe_columns_schools(reduced_df_schools)
    dic_schools = dataframe_to_dict(renamed_df_schools)
    q = School.delete()
    q.execute()
    schools_stored = store_datas_in_dbb(dic_schools, School)
    schools_dbb = School.select().dicts()
    print(list(schools_dbb))
    show_graphe_merged_cities_and_schools(merged_dataframe)
    db.close()
# Out:
# [{'code_insee': '75056', 'name': 'PARIS', 'population': 2211000, 'latitude': Decimal('48.86'), 'longitude': Decimal('2.34445')}, {'code_insee': '13055', 'name': 'MARSEILLE', 'population': 851400, 'latitude': Decimal('43.2967'), 'longitude': Decimal('5.37639')}, {'code_insee': '69123', 'name': 'LYON', 'population': 474900, 'latitude': Decimal('45.7589'), 'longitude': Decimal('4.8413900000000005')}, {'code_insee': '31555', 'name': 'TOULOUSE', 'population': 439600, 'latitude': Decimal('43.6'), 'longitude': Decimal('1.43333')}, {'code_insee': '06088', 'name': 'NICE', 'population': 344900, 'latitude': Decimal('43.7'), 'longitude': Decimal('7.25')}, {'code_insee': '44109', 'name': 'NANTES', 'population': 283300, 'latitude': Decimal('47.2167'), 'longitude': Decimal('-1.55')}, {'code_insee': '67482', 'name': 'STRASBOURG', 'population': 272100, 'latitude': Decimal('48.5833'), 'longitude': Decimal('7.75')}, {'code_insee': '34172', 'name': 'MONTPELLIER', 'population': 253000, 'latitude': Decimal('43.6'), 'longitude': Decimal('3.8833300000000004')}, {'code_insee': '33063', 'name': 'BORDEAUX', 'population': 235900, 'latitude': Decimal('44.8333'), 'longitude': Decimal('-0.566667')}, {'code_insee': '59350', 'name': 'LILLE', 'population': 225800, 'latitude': Decimal('50.6333'), 'longitude': Decimal('3.0666700000000002')}, {'code_insee': '35238', 'name': 'RENNES', 'population': 206700, 'latitude': Decimal('48.0833'), 'longitude': Decimal('-1.68333')}, {'code_insee': '51454', 'name': 'REIMS', 'population': 181500, 'latitude': Decimal('49.25'), 'longitude': Decimal('4.03333')}, {'code_insee': '76351', 'name': 'LE HAVRE', 'population': 178800, 'latitude': Decimal('49.5'), 'longitude': Decimal('0.13333299999999998')}, {'code_insee': '42218', 'name': 'SAINT-ETIENNE', 'population': 172700, 'latitude': Decimal('45.4333'), 'longitude': Decimal('4.4')}, {'code_insee': '83137', 'name': 'TOULON', 'population': 166700, 'latitude': Decimal('43.1167'), 'longitude': Decimal('5.933330000000001')}, {'code_insee': '38185', 'name': 'GRENOBLE', 'population': 156700, 'latitude': Decimal('45.1667'), 'longitude': Decimal('5.71667')}, {'code_insee': '21231', 'name': 'DIJON', 'population': 151600, 'latitude': Decimal('47.3167'), 'longitude': Decimal('5.0166699999999995')}, {'code_insee': '49007', 'name': 'ANGERS', 'population': 148400, 'latitude': Decimal('47.4667'), 'longitude': Decimal('-0.55')}, {'code_insee': '97411', 'name': 'SAINT-DENIS', 'population': 145022, 'latitude': Decimal('1.71819'), 'longitude': Decimal('46.7107')}, {'code_insee': '72181', 'name': 'LE MANS', 'population': 143500, 'latitude': Decimal('48'), 'longitude': Decimal('0.2')}, {'code_insee': '13001', 'name': 'AIX-EN-PROVENCE', 'population': 142700, 'latitude': Decimal('43.5333'), 'longitude': Decimal('5.433330000000001')}, {'code_insee': '29019', 'name': 'BREST', 'population': 142100, 'latitude': Decimal('48.4'), 'longitude': Decimal('-4.4833300000000005')}, {'code_insee': '69266', 'name': 'VILLEURBANNE', 'population': 141100, 'latitude': Decimal('45.7667'), 'longitude': Decimal('4.88333')}, {'code_insee': '30189', 'name': 'NIMES', 'population': 140300, 'latitude': Decimal('43.8333'), 'longitude': Decimal('4.35')}, {'code_insee': '87085', 'name': 'LIMOGES', 'population': 140100, 'latitude': Decimal('45.85'), 'longitude': Decimal('1.25')}, {'code_insee': '63113', 'name': 'CLERMONT-FERRAND', 'population': 139000, 'latitude': Decimal('45.7833'), 'longitude': Decimal('3.08333')}, {'code_insee': '37261', 'name': 'TOURS', 'population': 135500, 'latitude': Decimal('47.3833'), 'longitude': Decimal('0.683333')}, {'code_insee': '80021', 'name': 'AMIENS', 'population': 134400, 'latitude': Decimal('49.9'), 'longitude': Decimal('2.3')}, {'code_insee': '57463', 'name': 'METZ', 'population': 122800, 'latitude': Decimal('49.1333'), 'longitude': Decimal('6.16667')}, {'code_insee': '25056', 'name': 'BESANCON', 'population': 117600, 'latitude': Decimal('47.25'), 'longitude': Decimal('6.03333')}, {'code_insee': '6 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-8b046742436d> in <module>
#      24     q = School.delete()
#      25     q.execute()
# ---> 26     schools_stored = store_datas_in_dbb(dic_schools, School)
#      27     schools_dbb = School.select().dicts()
#      28     print(list(schools_dbb))
#
# ~/Campus/Python/apps/cities/cities.py in store_datas_in_dbb(list_dict, model)
#      55
#      56 def store_datas_in_dbb(list_dict, model):
# ---> 57     return model.insert_many(list_dict).execute()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in inner(self, database, *args, **kwargs)
#    1843             raise InterfaceError('Query must be bound to a database in order '
#    1844                                  'to call "%s".' % method.__name__)
# -> 1845         return method(self, database, *args, **kwargs)
#    1846     return inner
#    1847
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in execute(self, database)
#    1914     @database_required
#    1915     def execute(self, database):
# -> 1916         return self._execute(database)
#    1917
#    1918     def _execute(self, database):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in _execute(self, database)
#    2663             self._returning = (self.table._primary_key,)
#    2664         try:
# -> 2665             return super(Insert, self)._execute(database)
#    2666         except self.DefaultValuesException:
#    2667             pass
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in _execute(self, database)
#    2398             cursor = self.execute_returning(database)
#    2399         else:
# -> 2400             cursor = database.execute(self)
#    2401         return self.handle_result(database, cursor)
#    2402
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in execute(self, query, commit, **context_options)
#    3067     def execute(self, query, commit=SENTINEL, **context_options):
#    3068         ctx = self.get_sql_context(**context_options)
# -> 3069         sql, params = ctx.sql(query).query()
#    3070         return self.execute_sql(sql, params, commit=commit)
#    3071
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in sql(self, obj)
#     604     def sql(self, obj):
#     605         if isinstance(obj, (Node, Context)):
# --> 606             return obj.__sql__(self)
#     607         elif is_model(obj):
#     608             return obj._meta.table.__sql__(self)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in __sql__(self, ctx)
#    2648                 self._query_type = Insert.QUERY
#    2649             else:
# -> 2650                 self._generate_insert(self._insert, ctx)
#    2651                 self._query_type = Insert.MULTI
#    2652
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/peewee.py in _generate_insert(self, insert, ctx)
#    2534                 for column in row:
#    2535                     if isinstance(column, basestring):
# -> 2536                         column = getattr(self.table, column)
#    2537                     accum.append(column)
#    2538
#
# AttributeError: type object 'School' has no attribute 'note_globale'
